# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset = pd.read_csv('C:\\Users\\naqiy\\Desktop\\Data science\\Melbourne_housing_FULL.csv')

# %%
dataset
# Out:
#            Suburb             Address  Rooms Type      Price Method  \
# 0      Abbotsford       68 Studley St      2    h        NaN     SS
# 1      Abbotsford        85 Turner St      2    h  1480000.0      S
# 2      Abbotsford     25 Bloomburg St      2    h  1035000.0      S
# 3      Abbotsford  18/659 Victoria St      3    u        NaN     VB
# 4      Abbotsford        5 Charles St      3    h  1465000.0     SP
# ...           ...                 ...    ...  ...        ...    ...
# 34852  Yarraville         13 Burns St      4    h  1480000.0     PI
# 34853  Yarraville       29A Murray St      2    h   888000.0     SP
# 34854  Yarraville      147A Severn St      2    t   705000.0      S
# 34855  Yarraville    12/37 Stephen St      3    h  1140000.0     SP
# 34856  Yarraville    3 Tarrengower St      2    h  1020000.0     PI
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 0             Jellis   3/09/2016       2.5    3067.0  ...       1.0  1.0
# 1             Biggin   3/12/2016       2.5    3067.0  ...       1.0  1.0
# 2             Biggin   4/02/2016       2.5    3067.0  ...       1.0  0.0
# 3             Rounds   4/02/2016       2.5    3067.0  ...       2.0  1.0
# 4             Biggin   4/03/2017       2.5    3067.0  ...       2.0  0.0
# ...              ...         ...       ...       ...  ...       ...  ...
# 34852            Jas  24/02/2018       6.3    3013.0  ...       1.0  3.0
# 34853        Sweeney  24/02/2018       6.3    3013.0  ...       2.0  1.0
# 34854            Jas  24/02/2018       6.3    3013.0  ...       1.0  2.0
# 34855  hockingstuart  24/02/2018       6.3    3013.0  ...       NaN  NaN
# 34856             RW  24/02/2018       6.3    3013.0  ...       1.0  0.0
#
#        Landsize  BuildingArea  YearBuilt               CouncilArea Lattitude  \
# 0         126.0           NaN        NaN        Yarra City Council -37.80140
# 1         202.0           NaN        NaN        Yarra City Council -37.79960
# 2         156.0          79.0     1900.0        Yarra City Council -37.80790
# 3           0.0           NaN        NaN        Yarra City Council -37.81140
# 4         134.0         150.0     1900.0        Yarra City Council -37.80930
# ...         ...           ...        ...                       ...       ...
# 34852     593.0           NaN        NaN  Maribyrnong City Council -37.81053
# 34853      98.0         104.0     2018.0  Maribyrnong City Council -37.81551
# 34854     220.0         120.0     2000.0  Maribyrnong City Council -37.82286
# 34855       NaN           NaN        NaN  Maribyrnong City Council       NaN
# 34856     250.0         103.0     1930.0  Maribyrnong City Council -37.81810
#
#        Longtitude             Regionname Propertycount
# 0       144.99580  Northern Metropolitan        4019.0
# 1       144.99840  Northern Metropolitan        4019.0
# 2       144.99340  Northern Metropolitan        4019.0
# 3       145.01160  Northern Metropolitan        4019.0
# 4       144.99440  Northern Metropolitan        4019.0
# ...           ...                    ...           ...
# 34852   144.88467   Western Metropolitan        6543.0
# 34853   144.88826   Western Metropolitan        6543.0
# 34854   144.87856   Western Metropolitan        6543.0
# 34855         NaN   Western Metropolitan        6543.0
# 34856   144.89351   Western Metropolitan        6543.0
#
# [34857 rows x 21 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34857 entries, 0 to 34856
# Data columns (total 21 columns):
# Suburb           34857 non-null object
# Address          34857 non-null object
# Rooms            34857 non-null int64
# Type             34857 non-null object
# Price            27247 non-null float64
# Method           34857 non-null object
# SellerG          34857 non-null object
# Date             34857 non-null object
# Distance         34856 non-null float64
# Postcode         34856 non-null float64
# Bedroom2         26640 non-null float64
# Bathroom         26631 non-null float64
# Car              26129 non-null float64
# Landsize         23047 non-null float64
# BuildingArea     13742 non-null float64
# YearBuilt        15551 non-null float64
# CouncilArea      34854 non-null object
# Lattitude        26881 non-null float64
# Longtitude       26881 non-null float64
# Regionname       34854 non-null object
# Propertycount    34854 non-null float64
# dtypes: float64(12), int64(1), object(8)
# memory usage: 5.6+ MB

# %%
#cleaning predictive variable "Y" by taking non-null values only
df=dataset[dataset['Price'].notna()]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27247 entries, 1 to 34856
# Data columns (total 21 columns):
# Suburb           27247 non-null object
# Address          27247 non-null object
# Rooms            27247 non-null int64
# Type             27247 non-null object
# Price            27247 non-null float64
# Method           27247 non-null object
# SellerG          27247 non-null object
# Date             27247 non-null object
# Distance         27246 non-null float64
# Postcode         27246 non-null float64
# Bedroom2         20806 non-null float64
# Bathroom         20800 non-null float64
# Car              20423 non-null float64
# Landsize         17982 non-null float64
# BuildingArea     10656 non-null float64
# YearBuilt        12084 non-null float64
# CouncilArea      27244 non-null object
# Lattitude        20993 non-null float64
# Longtitude       20993 non-null float64
# Regionname       27244 non-null object
# Propertycount    27244 non-null float64
# dtypes: float64(12), int64(1), object(8)
# memory usage: 4.6+ MB

# %%
df['Rooms_without_Bedrooms'] = df['Rooms'] - df['Bedroom2']
df
# Out:
# C:\Users\naqiy\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#            Suburb           Address  Rooms Type      Price Method  \
# 1      Abbotsford      85 Turner St      2    h  1480000.0      S
# 2      Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 4      Abbotsford      5 Charles St      3    h  1465000.0     SP
# 5      Abbotsford  40 Federation La      3    h   850000.0     PI
# 6      Abbotsford       55a Park St      4    h  1600000.0     VB
# ...           ...               ...    ...  ...        ...    ...
# 34852  Yarraville       13 Burns St      4    h  1480000.0     PI
# 34853  Yarraville     29A Murray St      2    h   888000.0     SP
# 34854  Yarraville    147A Severn St      2    t   705000.0      S
# 34855  Yarraville  12/37 Stephen St      3    h  1140000.0     SP
# 34856  Yarraville  3 Tarrengower St      2    h  1020000.0     PI
#
#              SellerG        Date  Distance  Postcode  ...  Car  Landsize  \
# 1             Biggin   3/12/2016       2.5    3067.0  ...  1.0     202.0
# 2             Biggin   4/02/2016       2.5    3067.0  ...  0.0     156.0
# 4             Biggin   4/03/2017       2.5    3067.0  ...  0.0     134.0
# 5             Biggin   4/03/2017       2.5    3067.0  ...  1.0      94.0
# 6             Nelson   4/06/2016       2.5    3067.0  ...  2.0     120.0
# ...              ...         ...       ...       ...  ...  ...       ...
# 34852            Jas  24/02/2018       6.3    3013.0  ...  3.0     593.0
# 34853        Sweeney  24/02/2018       6.3    3013.0  ...  1.0      98.0
# 34854            Jas  24/02/2018       6.3    3013.0  ...  2.0     220.0
# 34855  hockingstuart  24/02/2018       6.3    3013.0  ...  NaN       NaN
# 34856             RW  24/02/2018       6.3    3013.0  ...  0.0     250.0
#
#        BuildingArea  YearBuilt               CouncilArea  Lattitude  \
# 1               NaN        NaN        Yarra City Council  -37.79960
# 2              79.0     1900.0        Yarra City Council  -37.80790
# 4             150.0     1900.0        Yarra City Council  -37.80930
# 5               NaN        NaN        Yarra City Council  -37.79690
# 6             142.0     2014.0        Yarra City Council  -37.80720
# ...             ...        ...                       ...        ...
# 34852           NaN        NaN  Maribyrnong City Council  -37.81053
# 34853         104.0     2018.0  Maribyrnong City Council  -37.81551
# 34854         120.0     2000.0  Maribyrnong City Council  -37.82286
# 34855           NaN        NaN  Maribyrnong City Council        NaN
# 34856         103.0     1930.0  Maribyrnong City Council  -37.81810
#
#       Longtitude             Regionname  Propertycount Rooms_without_Bedrooms
# 1      144.99840  Northern Metropolitan         4019.0                    0.0
# 2      144.99340  Northern Metropolitan         4019.0                    0.0
# 4      144.99440  Northern Metropolitan         4019.0                    0.0
# 5      144.99690  Northern Metropolitan         4019.0                    0.0
# 6      144.99410  Northern Metropolitan         4019.0                    1.0
# ...          ...                    ...            ...                    ...
# 34852  144.88467   Western Metropolitan         6543.0                    0.0
# 34853  144.88826   Western Metropolitan         6543.0                    0.0
# 34854  144.87856   Western Metropolitan         6543.0                    0.0
# 34855        NaN   Western Metropolitan         6543.0                    NaN
# 34856  144.89351   Western Metropolitan         6543.0                    0.0
#
# [27247 rows x 22 columns]

# %%
df['Rooms_without_Bedrooms'].unique()
# Out:
# array([  0.,   1.,  -1.,  nan,   2.,  -2.,  -3.,   3.,   4.,  -5.,  -6.,
#        -17.,  -7.])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27247 entries, 1 to 34856
# Data columns (total 22 columns):
# Suburb                    27247 non-null object
# Address                   27247 non-null object
# Rooms                     27247 non-null int64
# Type                      27247 non-null object
# Price                     27247 non-null float64
# Method                    27247 non-null object
# SellerG                   27247 non-null object
# Date                      27247 non-null object
# Distance                  27246 non-null float64
# Postcode                  27246 non-null float64
# Bedroom2                  20806 non-null float64
# Bathroom                  20800 non-null float64
# Car                       20423 non-null float64
# Landsize                  17982 non-null float64
# BuildingArea              10656 non-null float64
# YearBuilt                 12084 non-null float64
# CouncilArea               27244 non-null object
# Lattitude                 20993 non-null float64
# Longtitude                20993 non-null float64
# Regionname                27244 non-null object
# Propertycount             27244 non-null float64
# Rooms_without_Bedrooms    20806 non-null float64
# dtypes: float64(13), int64(1), object(8)
# memory usage: 4.8+ MB

# %%
df = df.drop(['Bedroom2','Rooms_without_Bedrooms'],1)

# %%
df['Bathroom'].unique()
# Out:
# array([ 1.,  2., nan,  3.,  4.,  0.,  7.,  5.,  6.,  8.,  9.])

# %%
df['Bathroom'].value_counts()
# Out:
# 1.0    10527
# 2.0     8464
# 3.0     1537
# 4.0      176
# 5.0       46
# 0.0       34
# 6.0       10
# 8.0        3
# 7.0        2
# 9.0        1
# Name: Bathroom, dtype: int64

# %%
df.loc[df.Bathroom>6].head(7)
# Out:
#            Suburb          Address  Rooms Type      Price Method  \
# 616     Ashburton   115 Ashburn Gr      8    h  2950000.0      S
# 1004       Balwyn  29 Sevenoaks St      5    h  3900000.0     PI
# 8251      Preston    421 Murray Rd      4    h   760000.0     PI
# 17472  Camberwell   1088 Toorak Rd      8    h  2200000.0     PI
# 25717     Burwood      79 Elgar Rd     10    h  2315000.0     SP
# 26210     Mitcham   20 Harrison St     16    h  5000000.0      S
#
#              SellerG        Date  Distance  Postcode  Bathroom  Car  Landsize  \
# 616    hockingstuart  10/09/2016      11.0    3147.0       7.0  4.0    1472.0
# 1004          Jellis  28/08/2016       9.7    3103.0       7.0  6.0       0.0
# 8251           Barry  22/05/2016       8.8    3072.0       8.0  7.0    1254.0
# 17472           Ross   8/07/2017       7.7    3124.0       8.0  4.0     650.0
# 25717         Buxton  28/10/2017      10.4    3125.0       9.0  2.0     612.0
# 26210         Buxton  28/10/2017      17.2    3132.0       8.0  8.0       NaN
#
#        BuildingArea  YearBuilt              CouncilArea  Lattitude  \
# 616           618.0     2009.0  Boroondara City Council  -37.87290
# 1004            NaN        NaN  Boroondara City Council  -37.80490
# 8251          280.0     1928.0     Darebin City Council  -37.73670
# 17472           NaN        NaN  Boroondara City Council  -37.84812
# 25717         466.0     2015.0      Monash City Council  -37.84461
# 26210           NaN        NaN  Whitehorse City Council  -37.81405
#
#        Longtitude             Regionname  Propertycount
# 616     145.07880  Southern Metropolitan         3052.0
# 1004    145.07480  Southern Metropolitan         5682.0
# 8251    144.98950  Northern Metropolitan        14577.0
# 17472   145.07414  Southern Metropolitan         8920.0
# 25717   145.10968  Southern Metropolitan         5678.0
# 26210   145.19891   Eastern Metropolitan         6871.0

# %%
plt.scatter(df['Bathroom'],df['Landsize'])

# %%
df['BuildingArea']=df['BuildingArea'].fillna(0)

# %%
df['BuildingArea'].loc[df.BuildingArea<1].count()
# Out:
# 16652

# %%
sns.boxplot(data = df, y = 'Landsize')

# %%
df = df[~(df['BuildingArea'] < 1)]  
#check the deletion
df['BuildingArea'].loc[df.BuildingArea<1].count()
# Out:
# 0

# %%
df = df.reset_index()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10595 entries, 0 to 10594
# Data columns (total 21 columns):
# index            10595 non-null int64
# Suburb           10595 non-null object
# Address          10595 non-null object
# Rooms            10595 non-null int64
# Type             10595 non-null object
# Price            10595 non-null float64
# Method           10595 non-null object
# SellerG          10595 non-null object
# Date             10595 non-null object
# Distance         10595 non-null float64
# Postcode         10595 non-null float64
# Bathroom         10595 non-null float64
# Car              10420 non-null float64
# Landsize         9334 non-null float64
# BuildingArea     10595 non-null float64
# YearBuilt        10189 non-null float64
# CouncilArea      10595 non-null object
# Lattitude        10586 non-null float64
# Longtitude       10586 non-null float64
# Regionname       10595 non-null object
# Propertycount    10595 non-null float64
# dtypes: float64(11), int64(2), object(8)
# memory usage: 1.7+ MB

# %%
df
# Out:
#        index      Suburb           Address  Rooms Type      Price Method  \
# 0          2  Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 1          4  Abbotsford      5 Charles St      3    h  1465000.0     SP
# 2          6  Abbotsford       55a Park St      4    h  1600000.0     VB
# 3         11  Abbotsford      124 Yarra St      3    h  1876000.0      S
# 4         14  Abbotsford     98 Charles St      2    h  1636000.0      S
# ...      ...         ...               ...    ...  ...        ...    ...
# 10590  34847     Wollert   27 Birchmore Rd      3    h   500000.0     PI
# 10591  34849     Wollert   35 Kingscote Wy      3    h   570000.0     SP
# 10592  34853  Yarraville     29A Murray St      2    h   888000.0     SP
# 10593  34854  Yarraville    147A Severn St      2    t   705000.0      S
# 10594  34856  Yarraville  3 Tarrengower St      2    h  1020000.0     PI
#
#        SellerG        Date  Distance  ...  Bathroom  Car  Landsize  \
# 0       Biggin   4/02/2016       2.5  ...       1.0  0.0     156.0
# 1       Biggin   4/03/2017       2.5  ...       2.0  0.0     134.0
# 2       Nelson   4/06/2016       2.5  ...       1.0  2.0     120.0
# 3       Nelson   7/05/2016       2.5  ...       2.0  0.0     245.0
# 4       Nelson   8/10/2016       2.5  ...       1.0  2.0     256.0
# ...        ...         ...       ...  ...       ...  ...       ...
# 10590      Ray  24/02/2018      25.5  ...       2.0  2.0     383.0
# 10591       RW  24/02/2018      25.5  ...       2.0  2.0     404.0
# 10592  Sweeney  24/02/2018       6.3  ...       2.0  1.0      98.0
# 10593      Jas  24/02/2018       6.3  ...       1.0  2.0     220.0
# 10594       RW  24/02/2018       6.3  ...       1.0  0.0     250.0
#
#        BuildingArea  YearBuilt               CouncilArea Lattitude  \
# 0              79.0     1900.0        Yarra City Council -37.80790
# 1             150.0     1900.0        Yarra City Council -37.80930
# 2             142.0     2014.0        Yarra City Council -37.80720
# 3             210.0     1910.0        Yarra City Council -37.80240
# 4             107.0     1890.0        Yarra City Council -37.80600
# ...             ...        ...                       ...       ...
# 10590         118.0     2016.0   Whittlesea City Council -37.61940
# 10591         158.0     2012.0   Whittlesea City Council -37.61031
# 10592         104.0     2018.0  Maribyrnong City Council -37.81551
# 10593         120.0     2000.0  Maribyrnong City Council -37.82286
# 10594         103.0     1930.0  Maribyrnong City Council -37.81810
#
#        Longtitude             Regionname Propertycount
# 0       144.99340  Northern Metropolitan        4019.0
# 1       144.99440  Northern Metropolitan        4019.0
# 2       144.99410  Northern Metropolitan        4019.0
# 3       144.99930  Northern Metropolitan        4019.0
# 4       144.99540  Northern Metropolitan        4019.0
# ...           ...                    ...           ...
# 10590   145.03951  Northern Metropolitan        2940.0
# 10591   145.03393  Northern Metropolitan        2940.0
# 10592   144.88826   Western Metropolitan        6543.0
# 10593   144.87856   Western Metropolitan        6543.0
# 10594   144.89351   Western Metropolitan        6543.0
#
# [10595 rows x 21 columns]

# %%
df.loc[df.Landsize>30000].head(10)
# Out:
#        index          Suburb         Address  Rooms Type      Price Method  \
# 4990   15109     Maribyrnong  2/6 Horizon Dr      2    u   585000.0      S
# 7398   22632    New Gisborne  71 Hamilton Rd      5    h  1355000.0      S
# 8480   25964  Gisborne South   31 Stanton Ct      3    h   930000.0      S
# 9013   28694  Gisborne South   47 Tweddle Rd      4    h  1350000.0     SA
# 10372  34055    Bullengarook   11 Dohoney Rd      4    h   865000.0      S
#
#       SellerG        Date  Distance  ...  Bathroom  Car  Landsize  \
# 4990     Brad   3/06/2017       4.3  ...       2.0  2.0   37000.0
# 7398    Raine  23/09/2017      48.1  ...       3.0  5.0   44500.0
# 8480    Raine  28/10/2017      45.9  ...       2.0  4.0   40468.0
# 9013       RT  25/11/2017      45.9  ...       2.0  8.0   40469.0
# 10372   Raine  24/02/2018      45.9  ...       2.0  0.0   42800.0
#
#        BuildingArea  YearBuilt                   CouncilArea Lattitude  \
# 4990           90.0     2004.0      Maribyrnong City Council -37.77518
# 7398        44515.0        NaN  Macedon Ranges Shire Council -37.45392
# 8480          215.0        NaN  Macedon Ranges Shire Council -37.54812
# 9013          245.0     1990.0  Macedon Ranges Shire Council -37.54300
# 10372         180.0     2000.0  Macedon Ranges Shire Council -37.47154
#
#        Longtitude            Regionname Propertycount
# 4990    144.89254  Western Metropolitan        4918.0
# 7398    144.58864     Northern Victoria         849.0
# 8480    144.63257     Northern Victoria         290.0
# 9013    144.59690     Northern Victoria         290.0
# 10372   144.53828     Northern Victoria         249.0
#
# [5 rows x 21 columns]

# %%
df['BA-LS']= (df['BuildingArea']-df['Landsize'])

# %%
df
# Out:
#        index      Suburb           Address  Rooms Type      Price Method  \
# 0          2  Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 1          4  Abbotsford      5 Charles St      3    h  1465000.0     SP
# 2          6  Abbotsford       55a Park St      4    h  1600000.0     VB
# 3         11  Abbotsford      124 Yarra St      3    h  1876000.0      S
# 4         14  Abbotsford     98 Charles St      2    h  1636000.0      S
# ...      ...         ...               ...    ...  ...        ...    ...
# 10590  34847     Wollert   27 Birchmore Rd      3    h   500000.0     PI
# 10591  34849     Wollert   35 Kingscote Wy      3    h   570000.0     SP
# 10592  34853  Yarraville     29A Murray St      2    h   888000.0     SP
# 10593  34854  Yarraville    147A Severn St      2    t   705000.0      S
# 10594  34856  Yarraville  3 Tarrengower St      2    h  1020000.0     PI
#
#        SellerG        Date  Distance  ...  Car  Landsize  BuildingArea  \
# 0       Biggin   4/02/2016       2.5  ...  0.0     156.0          79.0
# 1       Biggin   4/03/2017       2.5  ...  0.0     134.0         150.0
# 2       Nelson   4/06/2016       2.5  ...  2.0     120.0         142.0
# 3       Nelson   7/05/2016       2.5  ...  0.0     245.0         210.0
# 4       Nelson   8/10/2016       2.5  ...  2.0     256.0         107.0
# ...        ...         ...       ...  ...  ...       ...           ...
# 10590      Ray  24/02/2018      25.5  ...  2.0     383.0         118.0
# 10591       RW  24/02/2018      25.5  ...  2.0     404.0         158.0
# 10592  Sweeney  24/02/2018       6.3  ...  1.0      98.0         104.0
# 10593      Jas  24/02/2018       6.3  ...  2.0     220.0         120.0
# 10594       RW  24/02/2018       6.3  ...  0.0     250.0         103.0
#
#        YearBuilt               CouncilArea  Lattitude Longtitude  \
# 0         1900.0        Yarra City Council  -37.80790  144.99340
# 1         1900.0        Yarra City Council  -37.80930  144.99440
# 2         2014.0        Yarra City Council  -37.80720  144.99410
# 3         1910.0        Yarra City Council  -37.80240  144.99930
# 4         1890.0        Yarra City Council  -37.80600  144.99540
# ...          ...                       ...        ...        ...
# 10590     2016.0   Whittlesea City Council  -37.61940  145.03951
# 10591     2012.0   Whittlesea City Council  -37.61031  145.03393
# 10592     2018.0  Maribyrnong City Council  -37.81551  144.88826
# 10593     2000.0  Maribyrnong City Council  -37.82286  144.87856
# 10594     1930.0  Maribyrnong City Council  -37.81810  144.89351
#
#                   Regionname  Propertycount  BA-LS
# 0      Northern Metropolitan         4019.0  -77.0
# 1      Northern Metropolitan         4019.0   16.0
# 2      Northern Metropolitan         4019.0   22.0
# 3      Northern Metropolitan         4019.0  -35.0
# 4      Northern Metropolitan         4019.0 -149.0
# ...                      ...            ...    ...
# 10590  Northern Metropolitan         2940.0 -265.0
# 10591  Northern Metropolitan         2940.0 -246.0
# 10592   Western Metropolitan         6543.0    6.0
# 10593   Western Metropolitan         6543.0 -100.0
# 10594   Western Metropolitan         6543.0 -147.0
#
# [10595 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10595 entries, 0 to 10594
# Data columns (total 22 columns):
# index            10595 non-null int64
# Suburb           10595 non-null object
# Address          10595 non-null object
# Rooms            10595 non-null int64
# Type             10595 non-null object
# Price            10595 non-null float64
# Method           10595 non-null object
# SellerG          10595 non-null object
# Date             10595 non-null object
# Distance         10595 non-null float64
# Postcode         10595 non-null float64
# Bathroom         10595 non-null float64
# Car              10420 non-null float64
# Landsize         9334 non-null float64
# BuildingArea     10595 non-null float64
# YearBuilt        10189 non-null float64
# CouncilArea      10595 non-null object
# Lattitude        10586 non-null float64
# Longtitude       10586 non-null float64
# Regionname       10595 non-null object
# Propertycount    10595 non-null float64
# BA-LS            9334 non-null float64
# dtypes: float64(12), int64(2), object(8)
# memory usage: 1.8+ MB

# %%
df=df.drop(['BA-LS'], axis=1)

# %%
df
# Out:
#        index      Suburb           Address  Rooms Type      Price Method  \
# 0          2  Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 1          4  Abbotsford      5 Charles St      3    h  1465000.0     SP
# 2          6  Abbotsford       55a Park St      4    h  1600000.0     VB
# 3         11  Abbotsford      124 Yarra St      3    h  1876000.0      S
# 4         14  Abbotsford     98 Charles St      2    h  1636000.0      S
# ...      ...         ...               ...    ...  ...        ...    ...
# 10590  34847     Wollert   27 Birchmore Rd      3    h   500000.0     PI
# 10591  34849     Wollert   35 Kingscote Wy      3    h   570000.0     SP
# 10592  34853  Yarraville     29A Murray St      2    h   888000.0     SP
# 10593  34854  Yarraville    147A Severn St      2    t   705000.0      S
# 10594  34856  Yarraville  3 Tarrengower St      2    h  1020000.0     PI
#
#        SellerG        Date  Distance  ...  Bathroom  Car  Landsize  \
# 0       Biggin   4/02/2016       2.5  ...       1.0  0.0     156.0
# 1       Biggin   4/03/2017       2.5  ...       2.0  0.0     134.0
# 2       Nelson   4/06/2016       2.5  ...       1.0  2.0     120.0
# 3       Nelson   7/05/2016       2.5  ...       2.0  0.0     245.0
# 4       Nelson   8/10/2016       2.5  ...       1.0  2.0     256.0
# ...        ...         ...       ...  ...       ...  ...       ...
# 10590      Ray  24/02/2018      25.5  ...       2.0  2.0     383.0
# 10591       RW  24/02/2018      25.5  ...       2.0  2.0     404.0
# 10592  Sweeney  24/02/2018       6.3  ...       2.0  1.0      98.0
# 10593      Jas  24/02/2018       6.3  ...       1.0  2.0     220.0
# 10594       RW  24/02/2018       6.3  ...       1.0  0.0     250.0
#
#        BuildingArea  YearBuilt               CouncilArea Lattitude  \
# 0              79.0     1900.0        Yarra City Council -37.80790
# 1             150.0     1900.0        Yarra City Council -37.80930
# 2             142.0     2014.0        Yarra City Council -37.80720
# 3             210.0     1910.0        Yarra City Council -37.80240
# 4             107.0     1890.0        Yarra City Council -37.80600
# ...             ...        ...                       ...       ...
# 10590         118.0     2016.0   Whittlesea City Council -37.61940
# 10591         158.0     2012.0   Whittlesea City Council -37.61031
# 10592         104.0     2018.0  Maribyrnong City Council -37.81551
# 10593         120.0     2000.0  Maribyrnong City Council -37.82286
# 10594         103.0     1930.0  Maribyrnong City Council -37.81810
#
#        Longtitude             Regionname Propertycount
# 0       144.99340  Northern Metropolitan        4019.0
# 1       144.99440  Northern Metropolitan        4019.0
# 2       144.99410  Northern Metropolitan        4019.0
# 3       144.99930  Northern Metropolitan        4019.0
# 4       144.99540  Northern Metropolitan        4019.0
# ...           ...                    ...           ...
# 10590   145.03951  Northern Metropolitan        2940.0
# 10591   145.03393  Northern Metropolitan        2940.0
# 10592   144.88826   Western Metropolitan        6543.0
# 10593   144.87856   Western Metropolitan        6543.0
# 10594   144.89351   Western Metropolitan        6543.0
#
# [10595 rows x 21 columns]

# %%
df1= df[df['Landsize'].notna()]
df1
# Out:
#        index      Suburb           Address  Rooms Type      Price Method  \
# 0          2  Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 1          4  Abbotsford      5 Charles St      3    h  1465000.0     SP
# 2          6  Abbotsford       55a Park St      4    h  1600000.0     VB
# 3         11  Abbotsford      124 Yarra St      3    h  1876000.0      S
# 4         14  Abbotsford     98 Charles St      2    h  1636000.0      S
# ...      ...         ...               ...    ...  ...        ...    ...
# 10590  34847     Wollert   27 Birchmore Rd      3    h   500000.0     PI
# 10591  34849     Wollert   35 Kingscote Wy      3    h   570000.0     SP
# 10592  34853  Yarraville     29A Murray St      2    h   888000.0     SP
# 10593  34854  Yarraville    147A Severn St      2    t   705000.0      S
# 10594  34856  Yarraville  3 Tarrengower St      2    h  1020000.0     PI
#
#        SellerG        Date  Distance  ...  Bathroom  Car  Landsize  \
# 0       Biggin   4/02/2016       2.5  ...       1.0  0.0     156.0
# 1       Biggin   4/03/2017       2.5  ...       2.0  0.0     134.0
# 2       Nelson   4/06/2016       2.5  ...       1.0  2.0     120.0
# 3       Nelson   7/05/2016       2.5  ...       2.0  0.0     245.0
# 4       Nelson   8/10/2016       2.5  ...       1.0  2.0     256.0
# ...        ...         ...       ...  ...       ...  ...       ...
# 10590      Ray  24/02/2018      25.5  ...       2.0  2.0     383.0
# 10591       RW  24/02/2018      25.5  ...       2.0  2.0     404.0
# 10592  Sweeney  24/02/2018       6.3  ...       2.0  1.0      98.0
# 10593      Jas  24/02/2018       6.3  ...       1.0  2.0     220.0
# 10594       RW  24/02/2018       6.3  ...       1.0  0.0     250.0
#
#        BuildingArea  YearBuilt               CouncilArea Lattitude  \
# 0              79.0     1900.0        Yarra City Council -37.80790
# 1             150.0     1900.0        Yarra City Council -37.80930
# 2             142.0     2014.0        Yarra City Council -37.80720
# 3             210.0     1910.0        Yarra City Council -37.80240
# 4             107.0     1890.0        Yarra City Council -37.80600
# ...             ...        ...                       ...       ...
# 10590         118.0     2016.0   Whittlesea City Council -37.61940
# 10591         158.0     2012.0   Whittlesea City Council -37.61031
# 10592         104.0     2018.0  Maribyrnong City Council -37.81551
# 10593         120.0     2000.0  Maribyrnong City Council -37.82286
# 10594         103.0     1930.0  Maribyrnong City Council -37.81810
#
#        Longtitude             Regionname Propertycount
# 0       144.99340  Northern Metropolitan        4019.0
# 1       144.99440  Northern Metropolitan        4019.0
# 2       144.99410  Northern Metropolitan        4019.0
# 3       144.99930  Northern Metropolitan        4019.0
# 4       144.99540  Northern Metropolitan        4019.0
# ...           ...                    ...           ...
# 10590   145.03951  Northern Metropolitan        2940.0
# 10591   145.03393  Northern Metropolitan        2940.0
# 10592   144.88826   Western Metropolitan        6543.0
# 10593   144.87856   Western Metropolitan        6543.0
# 10594   144.89351   Western Metropolitan        6543.0
#
# [9334 rows x 21 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9334 entries, 0 to 10594
# Data columns (total 21 columns):
# index            9334 non-null int64
# Suburb           9334 non-null object
# Address          9334 non-null object
# Rooms            9334 non-null int64
# Type             9334 non-null object
# Price            9334 non-null float64
# Method           9334 non-null object
# SellerG          9334 non-null object
# Date             9334 non-null object
# Distance         9334 non-null float64
# Postcode         9334 non-null float64
# Bathroom         9334 non-null float64
# Car              9198 non-null float64
# Landsize         9334 non-null float64
# BuildingArea     9334 non-null float64
# YearBuilt        8981 non-null float64
# CouncilArea      9334 non-null object
# Lattitude        9325 non-null float64
# Longtitude       9325 non-null float64
# Regionname       9334 non-null object
# Propertycount    9334 non-null float64
# dtypes: float64(11), int64(2), object(8)
# memory usage: 1.6+ MB

# %%
df1['SUB']= df1['Landsize']-df1['BuildingArea']
df1
# Out:
# C:\Users\naqiy\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        index      Suburb           Address  Rooms Type      Price Method  \
# 0          2  Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 1          4  Abbotsford      5 Charles St      3    h  1465000.0     SP
# 2          6  Abbotsford       55a Park St      4    h  1600000.0     VB
# 3         11  Abbotsford      124 Yarra St      3    h  1876000.0      S
# 4         14  Abbotsford     98 Charles St      2    h  1636000.0      S
# ...      ...         ...               ...    ...  ...        ...    ...
# 10590  34847     Wollert   27 Birchmore Rd      3    h   500000.0     PI
# 10591  34849     Wollert   35 Kingscote Wy      3    h   570000.0     SP
# 10592  34853  Yarraville     29A Murray St      2    h   888000.0     SP
# 10593  34854  Yarraville    147A Severn St      2    t   705000.0      S
# 10594  34856  Yarraville  3 Tarrengower St      2    h  1020000.0     PI
#
#        SellerG        Date  Distance  ...  Car  Landsize  BuildingArea  \
# 0       Biggin   4/02/2016       2.5  ...  0.0     156.0          79.0
# 1       Biggin   4/03/2017       2.5  ...  0.0     134.0         150.0
# 2       Nelson   4/06/2016       2.5  ...  2.0     120.0         142.0
# 3       Nelson   7/05/2016       2.5  ...  0.0     245.0         210.0
# 4       Nelson   8/10/2016       2.5  ...  2.0     256.0         107.0
# ...        ...         ...       ...  ...  ...       ...           ...
# 10590      Ray  24/02/2018      25.5  ...  2.0     383.0         118.0
# 10591       RW  24/02/2018      25.5  ...  2.0     404.0         158.0
# 10592  Sweeney  24/02/2018       6.3  ...  1.0      98.0         104.0
# 10593      Jas  24/02/2018       6.3  ...  2.0     220.0         120.0
# 10594       RW  24/02/2018       6.3  ...  0.0     250.0         103.0
#
#        YearBuilt               CouncilArea  Lattitude Longtitude  \
# 0         1900.0        Yarra City Council  -37.80790  144.99340
# 1         1900.0        Yarra City Council  -37.80930  144.99440
# 2         2014.0        Yarra City Council  -37.80720  144.99410
# 3         1910.0        Yarra City Council  -37.80240  144.99930
# 4         1890.0        Yarra City Council  -37.80600  144.99540
# ...          ...                       ...        ...        ...
# 10590     2016.0   Whittlesea City Council  -37.61940  145.03951
# 10591     2012.0   Whittlesea City Council  -37.61031  145.03393
# 10592     2018.0  Maribyrnong City Council  -37.81551  144.88826
# 10593     2000.0  Maribyrnong City Council  -37.82286  144.87856
# 10594     1930.0  Maribyrnong City Council  -37.81810  144.89351
#
#                   Regionname  Propertycount    SUB
# 0      Northern Metropolitan         4019.0   77.0
# 1      Northern Metropolitan         4019.0  -16.0
# 2      Northern Metropolitan         4019.0  -22.0
# 3      Northern Metropolitan         4019.0   35.0
# 4      Northern Metropolitan         4019.0  149.0
# ...                      ...            ...    ...
# 10590  Northern Metropolitan         2940.0  265.0
# 10591  Northern Metropolitan         2940.0  246.0
# 10592   Western Metropolitan         6543.0   -6.0
# 10593   Western Metropolitan         6543.0  100.0
# 10594   Western Metropolitan         6543.0  147.0
#
# [9334 rows x 22 columns]

# %%
df1 = df1[~(df1['SUB'] < 0)]  
#check the deletion
df1['SUB'].loc[df1.SUB<0].count()
df1=df1.reset_index()

# %%
df1
# Out:
#       level_0  index        Suburb           Address  Rooms Type      Price  \
# 0           0      2    Abbotsford   25 Bloomburg St      2    h  1035000.0
# 1           3     11    Abbotsford      124 Yarra St      3    h  1876000.0
# 2           4     14    Abbotsford     98 Charles St      2    h  1636000.0
# 3           5     18    Abbotsford     10 Valiant St      2    h  1097000.0
# 4           6     24    Abbotsford   40 Nicholson St      3    h  1350000.0
# ...       ...    ...           ...               ...    ...  ...        ...
# 7956    10589  34842  Williamstown     34 Twyford St      3    h  1400000.0
# 7957    10590  34847       Wollert   27 Birchmore Rd      3    h   500000.0
# 7958    10591  34849       Wollert   35 Kingscote Wy      3    h   570000.0
# 7959    10593  34854    Yarraville    147A Severn St      2    t   705000.0
# 7960    10594  34856    Yarraville  3 Tarrengower St      2    h  1020000.0
#
#      Method  SellerG        Date  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 0         S   Biggin   4/02/2016  ...  0.0     156.0          79.0     1900.0
# 1         S   Nelson   7/05/2016  ...  0.0     245.0         210.0     1910.0
# 2         S   Nelson   8/10/2016  ...  2.0     256.0         107.0     1890.0
# 3         S   Biggin   8/10/2016  ...  2.0     220.0          75.0     1900.0
# 4        VB   Nelson  12/11/2016  ...  2.0     214.0         190.0     2005.0
# ...     ...      ...         ...  ...  ...       ...           ...        ...
# 7956     SP  Sweeney  24/02/2018  ...  NaN     325.0         158.0     1995.0
# 7957     PI      Ray  24/02/2018  ...  2.0     383.0         118.0     2016.0
# 7958     SP       RW  24/02/2018  ...  2.0     404.0         158.0     2012.0
# 7959      S      Jas  24/02/2018  ...  2.0     220.0         120.0     2000.0
# 7960     PI       RW  24/02/2018  ...  0.0     250.0         103.0     1930.0
#
#                    CouncilArea  Lattitude  Longtitude             Regionname  \
# 0           Yarra City Council  -37.80790   144.99340  Northern Metropolitan
# 1           Yarra City Council  -37.80240   144.99930  Northern Metropolitan
# 2           Yarra City Council  -37.80600   144.99540  Northern Metropolitan
# 3           Yarra City Council  -37.80100   144.99890  Northern Metropolitan
# 4           Yarra City Council  -37.80850   144.99640  Northern Metropolitan
# ...                        ...        ...         ...                    ...
# 7956  Hobsons Bay City Council  -37.86871   144.90124   Western Metropolitan
# 7957   Whittlesea City Council  -37.61940   145.03951  Northern Metropolitan
# 7958   Whittlesea City Council  -37.61031   145.03393  Northern Metropolitan
# 7959  Maribyrnong City Council  -37.82286   144.87856   Western Metropolitan
# 7960  Maribyrnong City Council  -37.81810   144.89351   Western Metropolitan
#
#       Propertycount    SUB
# 0            4019.0   77.0
# 1            4019.0   35.0
# 2            4019.0  149.0
# 3            4019.0  145.0
# 4            4019.0   24.0
# ...             ...    ...
# 7956         6380.0  167.0
# 7957         2940.0  265.0
# 7958         2940.0  246.0
# 7959         6543.0  100.0
# 7960         6543.0  147.0
#
# [7961 rows x 23 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7961 entries, 0 to 7960
# Data columns (total 23 columns):
# level_0          7961 non-null int64
# index            7961 non-null int64
# Suburb           7961 non-null object
# Address          7961 non-null object
# Rooms            7961 non-null int64
# Type             7961 non-null object
# Price            7961 non-null float64
# Method           7961 non-null object
# SellerG          7961 non-null object
# Date             7961 non-null object
# Distance         7961 non-null float64
# Postcode         7961 non-null float64
# Bathroom         7961 non-null float64
# Car              7843 non-null float64
# Landsize         7961 non-null float64
# BuildingArea     7961 non-null float64
# YearBuilt        7687 non-null float64
# CouncilArea      7961 non-null object
# Lattitude        7954 non-null float64
# Longtitude       7954 non-null float64
# Regionname       7961 non-null object
# Propertycount    7961 non-null float64
# SUB              7961 non-null float64
# dtypes: float64(12), int64(3), object(8)
# memory usage: 1.4+ MB

# %%
df1['Date'].unique()
# Out:
# array(['4/02/2016', '7/05/2016', '8/10/2016', '12/11/2016', '15/10/2016',
#        '16/07/2016', '17/09/2016', '18/03/2017', '19/11/2016',
#        '25/02/2017', '27/11/2016', '28/05/2016', '30/07/2016',
#        '3/09/2016', '4/03/2017', '6/08/2016', '7/11/2016', '10/09/2016',
#        '11/02/2017', '16/04/2016', '18/06/2016', '22/05/2016',
#        '22/08/2016', '24/09/2016', '27/06/2016', '28/08/2016',
#        '12/06/2016', '3/12/2016', '4/06/2016', '23/04/2016', '14/05/2016',
#        '10/12/2016', '13/08/2016', '26/07/2016', '11/03/2017',
#        '8/04/2017', '29/04/2017', '6/05/2017', '20/05/2017', '22/04/2017',
#        '13/05/2017', '1/07/2017', '3/06/2017', '17/06/2017', '24/06/2017',
#        '27/05/2017', '8/07/2017', '12/08/2017', '15/07/2017',
#        '22/07/2017', '29/07/2017', '3/09/2017', '9/09/2017', '16/09/2017',
#        '19/08/2017', '23/09/2017', '26/08/2017', '7/10/2017',
#        '14/10/2017', '21/10/2017', '28/10/2017', '30/09/2017',
#        '4/11/2017', '11/11/2017', '18/11/2017', '25/11/2017', '6/01/2018',
#        '9/12/2017', '3/02/2018', '10/02/2018', '20/01/2018', '27/01/2018',
#        '3/03/2018', '10/03/2018', '17/02/2018', '17/03/2018',
#        '24/02/2018'], dtype=object)

# %%
df1['YearBuilt'].unique()
# Out:
# array([1900., 1910., 1890., 2005., 1880., 1985.,   nan, 1950., 1930.,
#        2016., 2009., 1980., 2011., 2015., 2013., 2012., 1975., 1993.,
#        1960., 1995., 2010., 1925., 2004., 1970., 2008., 1920., 1962.,
#        1955., 1988., 1953., 1990., 1965., 2007., 2014., 1996., 1967.,
#        1889., 1888., 1935., 2000., 1998., 1887., 1904., 1978., 1939.,
#        1940., 2003., 1938., 2006., 1945., 1947., 1958., 2017., 1992.,
#        1961., 1977., 2001., 1948., 1927., 1997., 1981., 1943., 1974.,
#        1928., 1926., 2002., 1999., 1949., 1905., 1924., 1991., 1942.,
#        1973., 1972., 1969., 1915., 2018., 1916., 1982., 1957., 1897.,
#        1994., 1923., 1983., 1903., 1976., 1830., 1986., 1937., 1908.,
#        1913., 1917., 1885., 1854., 1941., 1951., 1946., 1966., 1956.,
#        1968., 1984., 1901., 1987., 1959., 1979., 1933., 1919., 1886.,
#        1906., 1971., 1875., 1934., 1918., 1912., 1860., 1894., 1884.,
#        1963., 1895., 1907., 1902., 1952., 1954., 1922., 1921., 1872.,
#        1989., 1863., 1196., 1892., 1936., 1964., 1929., 1893., 1881.,
#        1898., 1891., 1899., 1914., 2019., 1911.])

# %%
df1['Lattitude']= df1['Lattitude'].fillna(df1['Lattitude'].median())
df1['Longtitude']= df1['Longtitude'].fillna(df1['Longtitude'].median())
df1['YearBuilt']= df1['YearBuilt'].fillna(df1['YearBuilt'].median())

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7961 entries, 0 to 7960
# Data columns (total 23 columns):
# level_0          7961 non-null int64
# index            7961 non-null int64
# Suburb           7961 non-null object
# Address          7961 non-null object
# Rooms            7961 non-null int64
# Type             7961 non-null object
# Price            7961 non-null float64
# Method           7961 non-null object
# SellerG          7961 non-null object
# Date             7961 non-null object
# Distance         7961 non-null float64
# Postcode         7961 non-null float64
# Bathroom         7961 non-null float64
# Car              7843 non-null float64
# Landsize         7961 non-null float64
# BuildingArea     7961 non-null float64
# YearBuilt        7961 non-null float64
# CouncilArea      7961 non-null object
# Lattitude        7961 non-null float64
# Longtitude       7961 non-null float64
# Regionname       7961 non-null object
# Propertycount    7961 non-null float64
# SUB              7961 non-null float64
# dtypes: float64(12), int64(3), object(8)
# memory usage: 1.4+ MB

# %%
df1['Car']=df1['Car'].fillna(0)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7961 entries, 0 to 7960
# Data columns (total 23 columns):
# level_0          7961 non-null int64
# index            7961 non-null int64
# Suburb           7961 non-null object
# Address          7961 non-null object
# Rooms            7961 non-null int64
# Type             7961 non-null object
# Price            7961 non-null float64
# Method           7961 non-null object
# SellerG          7961 non-null object
# Date             7961 non-null object
# Distance         7961 non-null float64
# Postcode         7961 non-null float64
# Bathroom         7961 non-null float64
# Car              7961 non-null float64
# Landsize         7961 non-null float64
# BuildingArea     7961 non-null float64
# YearBuilt        7961 non-null float64
# CouncilArea      7961 non-null object
# Lattitude        7961 non-null float64
# Longtitude       7961 non-null float64
# Regionname       7961 non-null object
# Propertycount    7961 non-null float64
# SUB              7961 non-null float64
# dtypes: float64(12), int64(3), object(8)
# memory usage: 1.4+ MB

# %%
df1['houseAge'] = 2020-df1['YearBuilt']

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7961 entries, 0 to 7960
# Data columns (total 24 columns):
# level_0          7961 non-null int64
# index            7961 non-null int64
# Suburb           7961 non-null object
# Address          7961 non-null object
# Rooms            7961 non-null int64
# Type             7961 non-null object
# Price            7961 non-null float64
# Method           7961 non-null object
# SellerG          7961 non-null object
# Date             7961 non-null object
# Distance         7961 non-null float64
# Postcode         7961 non-null float64
# Bathroom         7961 non-null float64
# Car              7961 non-null float64
# Landsize         7961 non-null float64
# BuildingArea     7961 non-null float64
# YearBuilt        7961 non-null float64
# CouncilArea      7961 non-null object
# Lattitude        7961 non-null float64
# Longtitude       7961 non-null float64
# Regionname       7961 non-null object
# Propertycount    7961 non-null float64
# SUB              7961 non-null float64
# houseAge         7961 non-null float64
# dtypes: float64(13), int64(3), object(8)
# memory usage: 1.5+ MB

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df1.corr(),cmap = 'coolwarm',linewidth = 1,annot= True, annot_kws={"size": 9})
plt.title('Variable Correlation')
# Out:
# Text(0.5, 1, 'Variable Correlation')

# %%
df1['Regionname'].unique()
# Out:
# array(['Northern Metropolitan', 'Western Metropolitan',
#        'Southern Metropolitan', 'Eastern Metropolitan',
#        'South-Eastern Metropolitan', 'Northern Victoria',
#        'Eastern Victoria', 'Western Victoria'], dtype=object)

# %%
df1['Method'].unique()
# Out:
# array(['S', 'VB', 'PI', 'SP', 'SA'], dtype=object)

# %%
plt.scatter(df1.Method, df1.Price)

# %%
plt.scatter(df1.Regionname, df1.Price)

# %%
df2=df1
df2['RegionName']=df2['Regionname'].astype('category').cat.codes
df2['Method']=df2['Method'].astype('category').cat.codes
df2['SellerG']=df2['SellerG'].astype('category').cat.codes
df2['Type']=df2['Type'].astype('category').cat.codes
df2['Suburb']=df2['Suburb'].astype('category').cat.codes
df2['Address']=df2['Address'].astype('category').cat.codes
df2.corr()
# Out:
#                 level_0     index    Suburb   Address     Rooms      Type  \
# level_0        1.000000  0.998477  0.186426  0.005762  0.144950 -0.180029
# index          0.998477  1.000000  0.173292  0.005908  0.146333 -0.181628
# Suburb         0.186426  0.173292  1.000000  0.021575 -0.028356 -0.035317
# Address        0.005762  0.005908  0.021575  1.000000  0.033001 -0.115294
# Rooms          0.144950  0.146333 -0.028356  0.033001  1.000000 -0.407170
# Type          -0.180029 -0.181628 -0.035317 -0.115294 -0.407170  1.000000
# Price         -0.081101 -0.077568 -0.134477  0.067295  0.412541 -0.265612
# Method         0.062581  0.062698  0.017764  0.008542  0.013198  0.017649
# SellerG       -0.005161 -0.006712  0.053564  0.001211 -0.016439 -0.002265
# Distance       0.323770  0.322150  0.034501 -0.040079  0.199677 -0.126813
# Postcode       0.140294  0.141760  0.000040 -0.003751  0.094855 -0.030378
# Bathroom       0.072119  0.074346 -0.059335  0.022243  0.616335 -0.163265
# Car            0.096281  0.097240 -0.026087  0.009221  0.357286 -0.177672
# Landsize       0.040109  0.038754  0.001535 -0.003296  0.026202  0.077832
# BuildingArea   0.064528  0.067332 -0.054983  0.040295  0.633392 -0.288339
# YearBuilt      0.128394  0.127687  0.014927 -0.069297  0.085412  0.262179
# Lattitude      0.069348  0.067953  0.124568  0.005964 -0.022115 -0.056502
# Longtitude    -0.008699 -0.007937 -0.164244 -0.001954  0.087259  0.023590
# Propertycount  0.037451  0.038703  0.103263  0.001265 -0.045165  0.030744
# SUB            0.035892  0.034351  0.005156 -0.005951 -0.015475  0.096874
# houseAge      -0.128394 -0.127687 -0.014927  0.069297 -0.085412 -0.262179
# RegionName    -0.094834 -0.093020 -0.000374  0.008894 -0.002542  0.029208
#
#                   Price    Method   SellerG  Distance  ...       Car  \
# level_0       -0.081101  0.062581 -0.005161  0.323770  ...  0.096281
# index         -0.077568  0.062698 -0.006712  0.322150  ...  0.097240
# Suburb        -0.134477  0.017764  0.053564  0.034501  ... -0.026087
# Address        0.067295  0.008542  0.001211 -0.040079  ...  0.009221
# Rooms          0.412541  0.013198 -0.016439  0.199677  ...  0.357286
# Type          -0.265612  0.017649 -0.002265 -0.126813  ... -0.177672
# Price          1.000000  0.019368 -0.055037 -0.321203  ...  0.155535
# Method         0.019368  1.000000 -0.018859 -0.033236  ...  0.012417
# SellerG       -0.055037 -0.018859  1.000000  0.037287  ...  0.011421
# Distance      -0.321203 -0.033236  0.037287  1.000000  ...  0.221414
# Postcode       0.026913 -0.008980  0.001180  0.525620  ...  0.056035
# Bathroom       0.428801  0.019750 -0.024947  0.099978  ...  0.285134
# Car            0.155535  0.012417  0.011421  0.221414  ...  1.000000
# Landsize       0.015531  0.000503  0.009223  0.104084  ...  0.090078
# BuildingArea   0.508938  0.003698 -0.035597  0.107031  ...  0.311424
# YearBuilt     -0.297930 -0.014463 -0.000209  0.396681  ...  0.193031
# Lattitude     -0.253363 -0.006405  0.013711 -0.065779  ... -0.002649
# Longtitude     0.219325 -0.033805 -0.083111  0.147464  ...  0.033323
# Propertycount -0.044558 -0.031447  0.061444  0.033099  ... -0.015553
# SUB           -0.017962  0.000260  0.011573  0.097119  ...  0.069646
# houseAge       0.297930  0.014463  0.000209 -0.396681  ... -0.193031
# RegionName     0.110095  0.033709  0.014357 -0.132392  ...  0.014980
#
#                Landsize  BuildingArea  YearBuilt  Lattitude  Longtitude  \
# level_0        0.040109      0.064528   0.128394   0.069348   -0.008699
# index          0.038754      0.067332   0.127687   0.067953   -0.007937
# Suburb         0.001535     -0.054983   0.014927   0.124568   -0.164244
# Address       -0.003296      0.040295  -0.069297   0.005964   -0.001954
# Rooms          0.026202      0.633392   0.085412  -0.022115    0.087259
# Type           0.077832     -0.288339   0.262179  -0.056502    0.023590
# Price          0.015531      0.508938  -0.297930  -0.253363    0.219325
# Method         0.000503      0.003698  -0.014463  -0.006405   -0.033805
# SellerG        0.009223     -0.035597  -0.000209   0.013711   -0.083111
# Distance       0.104084      0.107031   0.396681  -0.065779    0.147464
# Postcode       0.073376      0.098151   0.110252  -0.157064    0.341850
# Bathroom       0.045878      0.611889   0.231812  -0.059145    0.115340
# Car            0.090078      0.311424   0.193031  -0.002649    0.033323
# Landsize       1.000000      0.044657   0.063921   0.037674   -0.024599
# BuildingArea   0.044657      1.000000   0.146123  -0.062975    0.115084
# YearBuilt      0.063921      0.146123   1.000000   0.110378   -0.017778
# Lattitude      0.037674     -0.062975   0.110378   1.000000   -0.346258
# Longtitude    -0.024599      0.115084  -0.017778  -0.346258    1.000000
# Propertycount -0.026320     -0.036621   0.001891   0.028386    0.023661
# SUB            0.997835     -0.021141   0.054351   0.041849   -0.032194
# houseAge      -0.063921     -0.146123  -1.000000  -0.110378    0.017778
# RegionName    -0.016642      0.029217  -0.037479  -0.267279   -0.530146
#
#                Propertycount       SUB  houseAge  RegionName
# level_0             0.037451  0.035892 -0.128394   -0.094834
# index               0.038703  0.034351 -0.127687   -0.093020
# Suburb              0.103263  0.005156 -0.014927   -0.000374
# Address             0.001265 -0.005951  0.069297    0.008894
# Rooms              -0.045165 -0.015475 -0.085412   -0.002542
# Type                0.030744  0.096874 -0.262179    0.029208
# Price              -0.044558 -0.017962  0.297930    0.110095
# Method             -0.031447  0.000260  0.014463    0.033709
# SellerG             0.061444  0.011573  0.000209    0.014357
# Distance            0.033099  0.097119 -0.396681   -0.132392
# Postcode            0.031316  0.066971 -0.110252   -0.084909
# Bathroom           -0.043507  0.005632 -0.231812    0.027897
# Car                -0.015553  0.069646 -0.193031    0.014980
# Landsize           -0.026320  0.997835 -0.063921   -0.016642
# BuildingArea       -0.036621 -0.021141 -0.146123    0.029217
# YearBuilt           0.001891  0.054351 -1.000000   -0.037479
# Lattitude           0.028386  0.041849 -0.110378   -0.267279
# Longtitude          0.023661 -0.032194  0.017778   -0.530146
# Propertycount       1.000000 -0.023929 -0.001891   -0.134536
# SUB                -0.023929  1.000000 -0.054351   -0.018579
# houseAge           -0.001891 -0.054351  1.000000    0.037479
# RegionName         -0.134536 -0.018579  0.037479    1.000000
#
# [22 rows x 22 columns]

# %%
plt.figure(figsize=(15,6))
sns.heatmap(df2.corr(),cmap = 'coolwarm',linewidth = 1,annot= True, annot_kws={"size": 9})
plt.title('Variable Correlation')
# Out:
# Text(0.5, 1, 'Variable Correlation')

# %%
df2['Type'].unique()
# Out:
# array([0, 2, 1], dtype=int64)

# %%
df1['Type'].unique()
# Out:
# array([0, 2, 1], dtype=int64)

# %%
dataset= df2[['Rooms','Bathroom','BuildingArea','houseAge','YearBuilt','Distance','Price','Type']]
dataset
# Out:
#       Rooms  Bathroom  BuildingArea  houseAge  YearBuilt  Distance      Price  \
# 0         2       1.0          79.0     120.0     1900.0       2.5  1035000.0
# 1         3       2.0         210.0     110.0     1910.0       2.5  1876000.0
# 2         2       1.0         107.0     130.0     1890.0       2.5  1636000.0
# 3         2       1.0          75.0     120.0     1900.0       2.5  1097000.0
# 4         3       2.0         190.0      15.0     2005.0       2.5  1350000.0
# ...     ...       ...           ...       ...        ...       ...        ...
# 7956      3       2.0         158.0      25.0     1995.0       6.8  1400000.0
# 7957      3       2.0         118.0       4.0     2016.0      25.5   500000.0
# 7958      3       2.0         158.0       8.0     2012.0      25.5   570000.0
# 7959      2       1.0         120.0      20.0     2000.0       6.3   705000.0
# 7960      2       1.0         103.0      90.0     1930.0       6.3  1020000.0
#
#       Type
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ...    ...
# 7956     0
# 7957     0
# 7958     0
# 7959     1
# 7960     0
#
# [7961 rows x 8 columns]

# %%
dataset.to_csv('C:\\Users\\naqiy\\Desktop\\Data science\\Melbourne_housing_FULL_final.csv', index=False)

# %% [markdown]
# # Clustering with Type, Rooms and Distance

# %%
dataset
# Out:
#       Rooms  Bathroom  BuildingArea  houseAge  YearBuilt  Distance      Price  \
# 0         2       1.0          79.0     120.0     1900.0       2.5  1035000.0
# 1         3       2.0         210.0     110.0     1910.0       2.5  1876000.0
# 2         2       1.0         107.0     130.0     1890.0       2.5  1636000.0
# 3         2       1.0          75.0     120.0     1900.0       2.5  1097000.0
# 4         3       2.0         190.0      15.0     2005.0       2.5  1350000.0
# ...     ...       ...           ...       ...        ...       ...        ...
# 7956      3       2.0         158.0      25.0     1995.0       6.8  1400000.0
# 7957      3       2.0         118.0       4.0     2016.0      25.5   500000.0
# 7958      3       2.0         158.0       8.0     2012.0      25.5   570000.0
# 7959      2       1.0         120.0      20.0     2000.0       6.3   705000.0
# 7960      2       1.0         103.0      90.0     1930.0       6.3  1020000.0
#
#       Type
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ...    ...
# 7956     0
# 7957     0
# 7958     0
# 7959     1
# 7960     0
#
# [7961 rows x 8 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7961 entries, 0 to 7960
# Data columns (total 8 columns):
# Rooms           7961 non-null int64
# Bathroom        7961 non-null float64
# BuildingArea    7961 non-null float64
# houseAge        7961 non-null float64
# YearBuilt       7961 non-null float64
# Distance        7961 non-null float64
# Price           7961 non-null float64
# Type            7961 non-null int8
# dtypes: float64(6), int64(1), int8(1)
# memory usage: 443.3 KB

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler  
from scipy import stats
from sklearn.cluster import KMeans
from sklearn import metrics
from sklearn.preprocessing import scale 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge, RidgeCV, Lasso, LassoCV
from sklearn.metrics import mean_squared_error
# %matplotlib inline

# %%
dataset_c = dataset[['Type','Price']]
from sklearn import preprocessing
x = dataset_c              #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df_c = pd.DataFrame(x_scaled)
df_c.head()
# Out:
#      0         1
# 0  0.0  0.101928
# 1  0.0  0.196753
# 2  0.0  0.169692
# 3  0.0  0.108919
# 4  0.0  0.137445

# %%
# Choosing the optimal k
from scipy.spatial.distance import cdist, pdist

k_range = range(1,10)
# Try clustering the data for k values ranging 1 to 10
k_means_var = [KMeans(n_clusters = k).fit(df_c) for k in k_range]
centroids = [X.cluster_centers_ for X in k_means_var]

k_euclid = [cdist(df_c, cent, 'euclidean') for cent in centroids]
dist = [np.min(ke, axis=1) for ke in k_euclid]

# Calculate within-cluster sum of squares
wcss = [sum(d**2) for d in dist]

# Visualize the elbow method for determining k
import matplotlib.pyplot as plt
plt.plot(k_range, wcss)
plt.xlabel('Range of k')
plt.ylabel('RSS within cluster')
plt.title('Elbow plot of Type V/S Price')
# plt.savefig('Images/Elbow_5')
plt.show()

# %%
kmeans = KMeans(n_clusters=4, random_state=0).fit(df_c)
labels = kmeans.labels_
#Glue back to originaal data
df_c['clusters'] = labels
df2_C = df_c.rename(columns = {0 : 'Type', 1: 'Price'})

# %%
sns.lmplot('Type', 'Price', data = df2_C, fit_reg=False,hue="clusters",  scatter_kws={"marker": "D", "s": 100})
plt.title('Type v/s Price')
plt.xlabel('Type')
plt.ylabel('Price')
#plt.savefig('Images/cluster_5.png')
plt.show()

# %%
dataset_c1 = dataset[['Rooms','Price']]
from sklearn import preprocessing
x = dataset_c              #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df_c1 = pd.DataFrame(x_scaled)
df_c1.head()
# Out:
#      0         1
# 0  0.0  0.101928
# 1  0.0  0.196753
# 2  0.0  0.169692
# 3  0.0  0.108919
# 4  0.0  0.137445

# %%
# Choosing the optimal k
from scipy.spatial.distance import cdist, pdist

k_range = range(1,10)
# Try clustering the data for k values ranging 1 to 10
k_means_var = [KMeans(n_clusters = k).fit(df_c1) for k in k_range]
centroids = [X.cluster_centers_ for X in k_means_var]

k_euclid = [cdist(df_c1, cent, 'euclidean') for cent in centroids]
dist = [np.min(ke, axis=1) for ke in k_euclid]

# Calculate within-cluster sum of squares
wcss = [sum(d**2) for d in dist]

# Visualize the elbow method for determining k
import matplotlib.pyplot as plt
plt.plot(k_range, wcss)
plt.xlabel('Range of k')
plt.ylabel('RSS within cluster')
plt.title('Elbow plot of Rooms V/S Price')
# plt.savefig('Images/Elbow_5')
plt.show()

# %%
kmeans = KMeans(n_clusters=4, random_state=0).fit(df_c)
labels = kmeans.labels_
#Glue back to originaal data
df_c1['clusters'] = labels
df2_C1 = df_c1.rename(columns = {0 : 'Rooms', 1: 'Price'})

# %%
sns.lmplot('Rooms', 'Price', data = df2_C1, fit_reg=False,hue="clusters",  scatter_kws={"marker": "D", "s": 100})
plt.title('Rooms v/s Price')
plt.xlabel('Rooms')
plt.ylabel('Price')
#plt.savefig('Images/cluster_5.png')
plt.show()

# %%
dataset_c2 = dataset[['Distance','Price']]
from sklearn import preprocessing
x = dataset_c2              #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df_dist = pd.DataFrame(x_scaled)
df_dist.head()
# Out:
#           0         1
# 0  0.052743  0.101928
# 1  0.052743  0.196753
# 2  0.052743  0.169692
# 3  0.052743  0.108919
# 4  0.052743  0.137445

# %%
# Choosing the optimal k
from scipy.spatial.distance import cdist, pdist

k_range = range(1,10)
# Try clustering the data for k values ranging 1 to 10
k_means_var = [KMeans(n_clusters = k).fit(df_dist) for k in k_range]
centroids = [X.cluster_centers_ for X in k_means_var]

k_euclid = [cdist(df_dist, cent, 'euclidean') for cent in centroids]
dist = [np.min(ke, axis=1) for ke in k_euclid]

# Calculate within-cluster sum of squares
wcss = [sum(d**2) for d in dist]

# Visualize the elbow method for determining k
import matplotlib.pyplot as plt
plt.plot(k_range, wcss)
plt.xlabel('Range of k')
plt.ylabel('RSS within cluster')
plt.title('Elbow plot of Distance V/S Price')
# plt.savefig('Images/Elbow_5')
plt.show()

# %%
kmeans = KMeans(n_clusters=4, random_state=0).fit(df_dist)
labels = kmeans.labels_
#Glue back to originaal data
df_dist['clusters'] = labels
df2_dist = df_dist.rename(columns = {0 : 'Distance', 1: 'Price'})

# %%
sns.lmplot('Distance', 'Price', data = df2_dist, fit_reg=False,hue="clusters",  scatter_kws={"marker": "D", "s": 100})
plt.title('Distance v/s Price')
plt.xlabel('Distance')
plt.ylabel('Price')
#plt.savefig('Images/cluster_5.png')
plt.show()

# %% [markdown]
# # Lasso Regression Model

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7961 entries, 0 to 7960
# Data columns (total 8 columns):
# Rooms           7961 non-null int64
# Bathroom        7961 non-null float64
# BuildingArea    7961 non-null float64
# houseAge        7961 non-null float64
# YearBuilt       7961 non-null float64
# Distance        7961 non-null float64
# Price           7961 non-null float64
# Type            7961 non-null int8
# dtypes: float64(6), int64(1), int8(1)
# memory usage: 443.3 KB

# %%
attributes= dataset.drop(['Price'],axis=1)

X_train, X_test, Y_train, Y_test = train_test_split(attributes, dataset['Price'],
test_size=0.33, random_state=5)

# %%
import sklearn
from sklearn import linear_model
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV, train_test_split
lasso_para = {'alpha':[1, .1, .02, .01, .001]}

print(GridSearchCV(linear_model.Lasso(), param_grid=lasso_para).fit(X_train, Y_train).best_estimator_,)
# Out:
# Lasso(alpha=0.001, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)
# C:\Users\naqiy\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)

# %%
import sklearn
from sklearn import linear_model
lasso = linear_model.Lasso(alpha = .001, max_iter = 1000, random_state=5)

lasso.fit(X_train, Y_train)

predictions = pd.DataFrame(data=lasso.predict(X_train).flatten())

predtransformed = predictions.apply(np.exp)

# %%
# train set 
from sklearn.metrics import mean_squared_error
# train set 
print('Coefficients:\n {}'.format(str(lasso.coef_)))
print('\nIntercept: {:>0.04f}'.format(lasso.intercept_))
print('\n' + 'RMSE: {:>0.04f}'.format(np.sqrt(mean_squared_error(Y_train, lasso.predict(X_train)))))
print('\nR^2: {:>0.04f}'.format(lasso.score(X_train, Y_train)))
# Out:
# Coefficients:
#  [ 8.44303785e+04  1.72242257e+05  3.39726361e+03  4.99436108e+03
#  -9.54265784e-12 -2.95480524e+04 -5.35075648e+04]
#
# Intercept: 138067.8057
#
# RMSE: 484147.7306
#
# R^2: 0.5015

# %%
predictions_test = lasso.predict(X_test)

print('Coefficients:\n {}'.format(str(lasso.coef_)))
print('\nIntercept: {:>0.04f}'.format(lasso.intercept_))
print('\n' + 'RMSE: {:>0.04f}'.format(np.sqrt(mean_squared_error(Y_test, lasso.predict(X_test)))))
print('\nR^2: {:>0.04f}'.format(lasso.score(X_test, Y_test)))
# Out:
# Coefficients:
#  [ 8.44303785e+04  1.72242257e+05  3.39726361e+03  4.99436108e+03
#  -9.54265784e-12 -2.95480524e+04 -5.35075648e+04]
#
# Intercept: 138067.8057
#
# RMSE: 468087.6284
#
# R^2: 0.5475

# %%
# K-fold cross validation 
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
CVSlasso = cross_val_score(lasso, attributes, dataset['Price'], cv=10)
print('Cross validated R^2: {}\n'.format(CVSlasso))
print('Mean cross validated R^2: {:>0.4f}'.format(CVSlasso.mean()))
# Out:
# Cross validated R^2: [0.47708514 0.58857423 0.55653538 0.50075474 0.54457127 0.43667971
#  0.3562498  0.50675244 0.51358776 0.52554188]
#
# Mean cross validated R^2: 0.5006

# %%
plt.figure(figsize = (10, 6))
plt.rcParams["axes.labelsize"] = 35
plt.rcParams["font.family"] = "Times New Roman"
plt.title('Residual Plot for Lasso Regression', fontsize=45)
plt.ylabel('Residual')
plt.xlabel('Price')
residuals = sns.residplot(Y_train, lasso.predict(X_train))
residuals_test = sns.residplot(Y_test, lasso.predict(X_test), color='r')
residuals_test.tick_params(labelsize=25)
plt.show()

# %%
import scipy as sp
lasso.fit(X_train, Y_train)
plt.rcParams["axes.labelsize"] = 20
lasso_prob_train = lasso.predict(X_train) - Y_train
plt.figure(figsize=(12,10))
sp.stats.probplot(lasso_prob_train, plot=plt, fit=True)
plt.title('Probability Plot for Lasso Regression', fontsize=30)
plt.show()

lasso_prob_test = lasso.predict(X_test) - Y_test
plt.figure(figsize=(12,10))
sp.stats.probplot(lasso_prob_test, plot=plt, fit=True)
plt.title('Probability Plot for Lasso Regression', fontsize=30)
plt.show()
